# %%
import pandas as pd

import pandas as pd
import numpy as np 
import pickle 
import time 
import random
import sklearn

import matplotlib.pyplot as plt

import seaborn as sns
sns.set(rc={'figure.figsize':(10,6)})
custom_colors = ["#4e89ae", "#c56183","#ed6663","#ffa372"]

import networkx as nx
import plotly.express as px 
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
raw_data=pd.read_csv('ApeCoin.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='BTC Price',title_x=0.5,
    shapes = [dict(x0='2022-03-17', x1='2022-03-17', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2022-05-26', x1='2022-05-26', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2022-03-17', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2022-05-26', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="f7414f9c-030f-4026-8899-148c4f20e5ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7414f9c-030f-4026-8899-148c4f20e5ec")) {                    Plotly.newPlot(                        "f7414f9c-030f-4026-8899-148c4f20e5ec",                        [{"close":[6.41,5.88,6.08,5.99,4.97,4.76,4.61,4.68,4.57,4.23,4.34,4.79,5.01,4.97,5.11,5.03,4.95,4.93,4.57,4.52,4.52,4.62,4.68,4.9,5.12,4.7,4.56,4.49,4.4,3.97,4.37,4.51,4.15,3.62,3.74,3.37,4.16,3.63,3.46,3.91,4.72,5.17,5.73,5.71,6.05,6.39,6.1,6.19,6.13,6.41,6.12,6.76,7.21,6.24,6.24,6.07,6.4,7.34,7.5,7.74,8.04,8.03,7.78,8.08,7.91,8.85,8.07,9.09,8.66,8.59,7.81,5.66,9.02,8.15,11.21,12.37,13.26,13.73,15.58,14.15,15.04,15.97,20.01,19.16,23.62,19.42,17.99,19.44,16.82,16.
# ...

# %%
raw_data=pd.read_csv('aave.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='BTC Price',title_x=0.5,
    shapes = [dict(x0='2020-10-03', x1='2020-10-03', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-05-23', x1='2021-05-23', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-07-21', x1='2021-07-21', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-11-12', x1='2021-11-12', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2020-10-03', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-05-23', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),
        dict(x='2021-07-21', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-11-12', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear')]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="ff0137c2-a29a-41bb-a97a-bfb99bbb8dcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff0137c2-a29a-41bb-a97a-bfb99bbb8dcb")) {                    Plotly.newPlot(                        "ff0137c2-a29a-41bb-a97a-bfb99bbb8dcb",                        [{"close":[95.53,90.83,95.64,96.71,88.46,92.64,90.5,90.82,79.62,68.36,69.9,77.71,81.9,71.92,71.19,62.99,60.72,63.06,57.62,57.83,56.15,56.97,59.66,60.03,65.39,65.44,70.04,71.24,67.94,62.26,65.53,61.79,54.03,49.43,57.47,56.32,66.24,62.29,59.19,70.83,76.91,87.71,95.92,96.56,99.49,105.97,103.76,106.73,107.14,111.05,106.55,113.12,117.35,95.31,95.36,92.21,101.52,101.86,106.58,99.33,94.46,91.33,90.3,91.53,81.77,92.6,84.22,91.87,86.72,82.24,77.54,81.89,105.35,100.9,125.84
# ...

# %%
raw_data=pd.read_csv('Augur.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2018-01-01', x1='2018-01-01', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2020-01-01', x1='2020-01-01', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-04-01', x1='2021-04-01', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2018-01-01', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),
        dict(x='2020-01-01', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-04-01', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear')]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="72839443-c76c-44d0-9fc7-16d6ce082e93" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72839443-c76c-44d0-9fc7-16d6ce082e93")) {                    Plotly.newPlot(                        "72839443-c76c-44d0-9fc7-16d6ce082e93",                        [{"close":[8.4,8.37,8.76,8.64,8.25,8.14,8.02,7.94,7.87,7.61,7.77,8.24,8.52,8.4,8.35,8.16,8.06,8.21,8.03,8.07,8.09,7.99,8.31,8.44,8.77,8.78,9.27,8.85,8.72,8.43,8.01,7.89,7.88,7.57,8.44,8.14,7.04,6.56,6.51,7.61,8.39,8.76,9.35,9.5,9.76,10.26,10.1,9.91,10.02,10.01,9.89,10.86,11.58,11.37,9.22,9.45,9.22,10.01,10.51,11.01,12.37,7.08,7.01,7.25,6.94,7.87,7.3,7.77,7.32,6.96,6.35,7.1,9.1,9.02,10.5,10.9,11.22,11.43,12.46,11.5,11.81,11.99,11.69,12.79,13.39,13.14,12.84,13.8,13.
# ...

# %%
raw_data=pd.read_csv('Barn.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-01-01', x1='2021-01-01', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-03-26', x1='2021-03-26', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-01-01', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-03-26', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="9c4c1b59-ef8e-44a7-aeb7-bd31b7edbbd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c4c1b59-ef8e-44a7-aeb7-bd31b7edbbd9")) {                    Plotly.newPlot(                        "9c4c1b59-ef8e-44a7-aeb7-bd31b7edbbd9",                        [{"close":[11.66,12.07,7.9,7.71,6.37,6.99,3.23,3.19,2.93,2.85,3.01,2.89,3.05,3.06,3.11,2.96,2.8,2.89,2.86,2.79,2.65,2.71,2.76,2.71,2.67,2.74,2.94,2.83,2.63,2.51,2.59,2.66,2.46,2.33,2.58,2.62,2.87,2.82,2.82,3.41,3.53,3.45,3.69,3.6,3.75,3.54,3.51,3.47,3.45,3.52,3.42,3.69,3.74,3.59,3.46,3.41,3.28,3.59,3.85,3.47,3.54,3.44,3.43,3.59,3.41,3.59,3.39,3.61,3.3,3.37,3.18,3.59,4.85,5.49,5.11,5.31,5.32,5.66,6.19,6.05,6.07,6.14,5.87,6.12,6.84,6.81,6.72,7.41,7.17,7.34,7.54,7.56
# ...

# %%
raw_data=pd.read_csv('Curve.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2020-08-16', x1='2020-08-16', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2020-08-16', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear')]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="7947375e-4330-405f-a81e-7aee3d945e2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7947375e-4330-405f-a81e-7aee3d945e2e")) {                    Plotly.newPlot(                        "7947375e-4330-405f-a81e-7aee3d945e2e",                        [{"close":[1.4,1.16,1.24,1.34,1.08,1.17,1.11,1.17,1.05,0.8784,0.8889,0.9549,1.02,1.01,1.05,0.9621,0.9599,0.8644,0.7951,0.777,0.7461,0.6825,0.7047,0.6975,0.7357,0.7513,0.821,0.8461,0.8308,0.6985,0.7244,0.7032,0.647,0.583,0.6622,0.6604,0.7668,0.7308,0.7137,0.867,0.9057,1.03,1.15,1.16,1.19,1.29,1.21,1.18,1.17,1.26,1.27,1.38,1.39,1.25,1.22,1.17,1.21,1.23,1.25,1.3,1.28,1.21,1.14,1.08,1.23,1.39,1.37,1.51,1.42,1.32,1.31,1.49,1.98,1.93,2.35,2.23,2.3,2.46,2.6,2.16,2.1,2.07
# ...

# %%
raw_data=pd.read_csv('Decent.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-10-28', x1='2021-10-28', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-12-05', x1='2021-12-05', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-10-28', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-12-05', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="3c89a334-25e0-4bdc-83b7-7441443b99c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c89a334-25e0-4bdc-83b7-7441443b99c0")) {                    Plotly.newPlot(                        "3c89a334-25e0-4bdc-83b7-7441443b99c0",                        [{"close":[0.9396,0.9205,1.0,0.9236,0.8389,0.8673,0.847,0.8364,0.8136,0.7857,0.8071,0.8696,0.9072,0.9029,0.9349,0.9145,0.8741,0.9057,0.8377,0.8359,0.8317,0.8792,0.8771,0.8868,0.9659,0.9325,1.02,0.9383,0.8948,0.837,0.8418,0.832,0.8274,0.7793,0.84,0.8076,0.9214,0.8222,0.8187,0.7947,0.8152,0.8911,0.9724,0.9791,1.02,1.02,0.9766,0.9805,0.9802,1.04,0.9852,1.09,1.09,0.9731,0.957,0.9283,0.9903,1.06,1.04,1.03,1.11,1.1,1.07,1.12,1.04,1.21,1.17,1.33,1.33,1.01,0.7081,0.7822,1
# ...

# %%
raw_data=pd.read_csv('Flamingo.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-03-01', x1='2021-03-01', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-05-07', x1='2021-05-07', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-07-21', x1='2021-07-21', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-11-30', x1='2021-11-30', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-03-01', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-05-07', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),
        dict(x='2021-07-21', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-11-30', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear')]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="599af878-c7b2-4b1e-9153-da0e1948b45c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("599af878-c7b2-4b1e-9153-da0e1948b45c")) {                    Plotly.newPlot(                        "599af878-c7b2-4b1e-9153-da0e1948b45c",                        [{"close":[0.1972,0.1747,0.1908,0.2078,0.1591,0.1721,0.157,0.1559,0.1702,0.1208,0.1127,0.1299,0.1203,0.1147,0.114,0.1073,0.1023,0.106,0.1076,0.1015,0.09619,0.09827,0.1056,0.1011,0.1059,0.1064,0.1132,0.1147,0.1125,0.1088,0.1181,0.1361,0.1165,0.1022,0.1099,0.1063,0.1225,0.1192,0.1336,0.1645,0.1506,0.1283,0.1175,0.1208,0.09999,0.09907,0.09426,0.09462,0.09341,0.09844,0.09456,0.1039,0.1033,0.09385,0.08972,0.0879,0.09149,0.1014,0.1022,0.1004,0.1016,0.09628,0.09341,0.098
# ...

# %%
raw_data=pd.read_csv('Harvest.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-08-11', x1='2021-08-11', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-08-11', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear')]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="4afc54a9-63b1-4d5a-a086-af46e90913c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4afc54a9-63b1-4d5a-a086-af46e90913c3")) {                    Plotly.newPlot(                        "4afc54a9-63b1-4d5a-a086-af46e90913c3",                        [{"close":[47.37,45.85,47.31,48.0,45.0,45.03,44.41,45.73,42.97,41.32,42.9,45.42,48.0,45.14,44.94,44.95,43.75,43.97,42.23,41.47,40.57,40.2,39.04,37.8,37.92,40.87,45.15,37.65,35.19,32.58,34.26,34.1,32.16,31.02,32.83,35.93,31.52,29.24,29.39,35.58,37.88,41.6,43.8,44.81,43.33,43.29,42.9,43.04,42.72,44.84,43.34,47.44,49.41,44.7,42.84,41.83,44.75,49.32,51.15,49.86,51.69,51.94,52.44,52.78,50.04,54.91,50.01,54.09,48.32,45.71,39.35,40.39,62.28,57.6,70.46,74.51,78.26,79.06,8
# ...

# %%
raw_data=pd.read_csv('Lido.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-07-20', x1='2021-07-20', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2022-04-03', x1='2022-04-03', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-07-20', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2022-04-03', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="9a6c302c-dcb4-4b4c-a3ea-5bc1ea95224d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a6c302c-dcb4-4b4c-a3ea-5bc1ea95224d")) {                    Plotly.newPlot(                        "9a6c302c-dcb4-4b4c-a3ea-5bc1ea95224d",                        [{"close":[1.61,1.58,1.52,1.52,1.63,1.36,1.14,0.9066,0.9447,0.6379,0.6239,0.6405,0.6825,0.7422,0.6662,0.6193,0.5679,0.5417,0.5068,0.4648,0.4549,0.4514,0.4992,0.5202,0.5733,0.6187,0.644,0.642,0.5475,0.5112,0.5441,0.5146,0.5153,0.4638,0.5797,0.5316,0.6164,0.6218,0.5939,0.8016,0.8468,0.997,1.02,1.01,1.06,1.06,1.04,1.02,1.01,1.03,1.03,1.05,1.22,1.17,1.03,1.07,1.01,1.08,1.1,1.18,1.32,1.33,1.31,1.42,1.37,1.51,1.43,1.47,1.48,1.49,1.41,1.52,1.97,2.03,2.81,2.75,2.79,2.82,3
# ...

# %%
raw_data=pd.read_csv('Ox.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2022-03-02', x1='2022-03-02', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2022-03-02', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="8a66ba57-5f59-4737-ab19-bc9158b2e155" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a66ba57-5f59-4737-ab19-bc9158b2e155")) {                    Plotly.newPlot(                        "8a66ba57-5f59-4737-ab19-bc9158b2e155",                        [{"close":[0.00195,0.001959,0.001863,0.001882,0.001944,0.001907,0.001943,0.001908,0.001941,0.001973,0.002027,0.002006,0.002052,0.002026,0.002037,0.002078,0.002086,0.002087,0.002154,0.002087,0.002059,0.002036,0.002109,0.002102,0.002125,0.002165,0.00217,0.002209,0.002229,0.002257,0.002225,0.002208,0.00219,0.0022,0.002261,0.002222,0.002248,0.002339,0.002273,0.002429,0.002558,0.002551,0.002584,0.002678,0.002718,0.002872,0.002855,0.00305,0.002994,0.002996,0.002952,0.00
# ...

# %%
raw_data=pd.read_csv('Sushi.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-07-01', x1='2021-07-01', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2021-12-29', x1='2021-12-29', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-07-01', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2021-12-29', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="741783c5-7f6e-4281-8592-c919061c7023" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("741783c5-7f6e-4281-8592-c919061c7023")) {                    Plotly.newPlot(                        "741783c5-7f6e-4281-8592-c919061c7023",                        [{"close":[1.42,1.32,1.42,1.51,1.4,1.45,1.41,1.39,1.24,1.12,1.14,1.31,1.24,1.16,1.18,1.15,1.09,1.09,1.02,0.9794,0.9651,0.987,1.05,1.09,1.15,1.15,1.25,1.29,1.25,1.19,1.24,1.11,1.04,0.9292,1.02,0.9525,1.11,1.01,0.965,1.14,1.19,1.37,1.49,1.5,1.56,1.61,1.55,1.58,1.55,1.68,1.63,1.88,1.69,1.49,1.53,1.42,1.48,1.65,1.67,1.53,1.46,1.45,1.3,1.36,1.26,1.43,1.26,1.39,1.32,1.43,1.16,1.33,1.79,1.77,2.11,2.14,2.25,2.28,2.62,2.33,2.36,2.39,2.32,2.7,2.99,3.0,2.91,3.28,3.37,3.42,3.
# ...

# %%
raw_data=pd.read_csv('Tracer.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2022-03-17', x1='2022-03-17', y0=0, y1=1, xref='x', yref='paper',line_width=2),
             dict(x0='2022-05-26', x1='2022-05-26', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2022-03-17', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bull'),
        dict(x='2022-05-26', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="73c91844-ea84-41d8-bfdd-452c8c1a8d98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73c91844-ea84-41d8-bfdd-452c8c1a8d98")) {                    Plotly.newPlot(                        "73c91844-ea84-41d8-bfdd-452c8c1a8d98",                        [{"close":[0.04715,0.04336,0.045,0.04707,0.03947,0.03931,0.03385,0.03174,0.02946,0.0281,0.02908,0.03606,0.03722,0.03867,0.03829,0.03359,0.03191,0.03169,0.03038,0.03013,0.02927,0.03059,0.03235,0.03415,0.03537,0.03735,0.04016,0.04083,0.03421,0.03168,0.0346,0.03459,0.03525,0.02961,0.03111,0.03002,0.03448,0.03626,0.03561,0.043,0.0454,0.04829,0.05105,0.05104,0.05321,0.05466,0.05465,0.05554,0.05488,0.05748,0.05823,0.06335,0.05682,0.04973,0.05031,0.04946,0.05004,0.05811,
# ...

# %%
raw_data=pd.read_csv('raid.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-09-11', x1='2021-09-11', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-09-11', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="1e479196-7459-4f1b-9fa5-7b104ec35311" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e479196-7459-4f1b-9fa5-7b104ec35311")) {                    Plotly.newPlot(                        "1e479196-7459-4f1b-9fa5-7b104ec35311",                        [{"close":[0.01285,0.01242,0.01257,0.01318,0.01124,0.0113,0.01045,0.01008,0.009465,0.008904,0.009403,0.009817,0.01022,0.01029,0.01036,0.009819,0.009386,0.007965,0.007459,0.007427,0.007384,0.007334,0.007317,0.007687,0.008021,0.008067,0.008316,0.008217,0.007687,0.007116,0.007461,0.007491,0.007229,0.006435,0.007019,0.006794,0.007772,0.007329,0.007292,0.008337,0.008688,0.009429,0.009887,0.009912,0.01003,0.01013,0.0099,0.009862,0.009546,0.009862,0.009563,0.01015,0.0101
# ...

# %%
raw_data=pd.read_csv('Meta.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-11-20', x1='2021-11-20', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-11-20', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="5e79d09b-5242-41ca-a872-a5ecec13da75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e79d09b-5242-41ca-a872-a5ecec13da75")) {                    Plotly.newPlot(                        "5e79d09b-5242-41ca-a872-a5ecec13da75",                        [{"close":[2.337e-07,2.272e-07,2.329e-07,2.282e-07,2.146e-07,2.14e-07,2.074e-07,2.07e-07,2.009e-07,1.965e-07,2.004e-07,2.085e-07,2.162e-07,2.161e-07,2.104e-07,2.082e-07,2.012e-07,2.026e-07,1.908e-07,1.794e-07,1.78e-07,1.796e-07,1.936e-07,2.017e-07,2.068e-07,2.083e-07,2.106e-07,2.112e-07,1.982e-07,1.856e-07,1.889e-07,1.87e-07,1.766e-07,1.623e-07,1.747e-07,1.706e-07,1.903e-07,1.828e-07,1.794e-07,2.067e-07,2.189e-07,2.355e-07,2.398e-07,2.316e-07,2.316e-07,2.334e-07,2
# ...

# %%
raw_data=pd.read_csv('bit.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-11-12', x1='2021-11-12', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-11-12', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="f225df10-72bb-48e3-86b4-f4e1103cd1c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f225df10-72bb-48e3-86b4-f4e1103cd1c2")) {                    Plotly.newPlot(                        "f225df10-72bb-48e3-86b4-f4e1103cd1c2",                        [{"close":[0.532,0.5043,0.5182,0.5294,0.4655,0.4618,0.4666,0.4672,0.4544,0.4392,0.4442,0.4495,0.4556,0.455,0.4519,0.4412,0.4349,0.438,0.4268,0.4267,0.4268,0.4259,0.4388,0.45,0.4623,0.4632,0.4672,0.4611,0.4317,0.4176,0.4245,0.4378,0.4333,0.4119,0.4228,0.4181,0.442,0.4594,0.45,0.4732,0.5101,0.542,0.5428,0.5494,0.5657,0.5718,0.5492,0.561,0.5292,0.6136,0.7091,0.7487,0.7887,0.7553,0.7227,0.7233,0.7489,0.7718,0.7804,0.7907,0.8027,0.8042,0.8043,0.8166,0.8176,0.847,0.8391
# ...

# %%
raw_data=pd.read_csv('yam.csv')
def date_format(df):
    if isinstance(df, pd.DataFrame):
        if 'Date' in df.columns:
            df.Date = pd.to_datetime(df.Date)
            df[['Year','Month','Day']] = df.Date.apply(lambda x: pd.Series(x.strftime("%Y-%m-%d").split("-")))
    else:
        print("Invalid entry, please use a data frame with a Date column.")
    return df

data=date_format(raw_data)
data['Close']=data['Close'].astype(float)
data['Open']=data['Open'].astype(float)
data['High']=data['High'].astype(float)
data['Low']=data['Low'].astype(float)
data['Year']=data['Year'].astype(int)
data['Month']=data['Month'].astype(int)
data['Day']=data['Day'].astype(int)

fig = go.Figure(data=go.Ohlc(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close']))

fig.update_layout(template='plotly_dark',
    title='Price over the years',
    xaxis_title="Year",
    yaxis_title='Price',title_x=0.5,
    shapes = [dict(x0='2021-03-04', x1='2021-03-04', y0=0, y1=1, xref='x', yref='paper',line_width=2)],
    annotations=[dict(x='2021-03-04', y=0.05, xref='x', yref='paper',showarrow=False, xanchor='left', text='bear'),]
)

fig.update_yaxes( # the y-axis is in dollars
    tickprefix="$", showgrid=False
)

fig.update_xaxes(
     showgrid=True
)

fig.show()
# Out:
# <div>                            <div id="b9ce223e-1c1d-41a5-8627-2d0ea2565010" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9ce223e-1c1d-41a5-8627-2d0ea2565010")) {                    Plotly.newPlot(                        "b9ce223e-1c1d-41a5-8627-2d0ea2565010",                        [{"close":[0.1568,0.1609,0.1632,0.1534,0.132,0.1352,0.115,0.1124,0.1049,0.1005,0.1057,0.1144,0.1224,0.1347,0.1368,0.122,0.1221,0.1386,0.1023,0.1067,0.1088,0.1086,0.1089,0.1132,0.1126,0.119,0.1207,0.1176,0.1079,0.109,0.1149,0.1145,0.1173,0.1016,0.1248,0.1227,0.1217,0.1271,0.1327,0.1511,0.1578,0.1698,0.1947,0.2,0.2081,0.1951,0.1885,0.1894,0.1886,0.2015,0.1988,0.2098,0.22,0.1845,0.1833,0.1892,0.1901,0.2035,0.2128,0.2538,0.2192,0.2176,0.2089,0.1772,0.1898,0.2071,0.157
# ...

# %%
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import yfinance as yf
#       3 import statsmodels.api as sm
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
data = pd.read_csv("ApeCoin.csv")
data = data.set_index('Date')
data
# Out:
#               Open     High      Low    Close           Volume  \
# Date
# 21-Jul-22   $5.87    $6.53    $5.67    $6.41     $518,964,129
# 20-Jul-22   $6.08    $6.48    $5.82    $5.88     $649,123,451
# 19-Jul-22   $5.99    $6.32    $5.65    $6.08     $707,018,190
# 18-Jul-22   $4.97    $6.21    $4.97    $5.99     $896,798,611
# 17-Jul-22   $4.76    $5.15    $4.65    $4.97     $433,491,766
# ...            ...      ...      ...      ...              ...
# 21-Mar-22   $9.60   $10.98    $9.59   $10.50   $2,104,738,824
# 20-Mar-22  $11.61   $11.91    $9.54    $9.60   $2,048,782,413
# 19-Mar-22  $13.00   $14.54   $11.52   $11.56   $2,837,336,308
# 18-Mar-22   $8.53   $17.75    $8.53   $12.96   $8,934,642,172
# 17-Mar-22   $1.00   $39.40    $1.00    $8.52               NaN
#
#                 Market Cap
# Date
# 21-Jul-22  $1,968,516,523
# 20-Jul-22  $1,802,912,911
# 19-Jul-22  $1,866,026,990
# 18-Jul-22  $1,838,347,793
# 17-Jul-22  $1,489,004,869
# ...                    ...
# ...

# %%
df = data['Close'].pct_change(period=2)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 df = data['Close'].pct_change(period=2)
#       2 df
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:10364, in NDFrame.pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10361     assert _data is not None  # needed for mypy
#   10362     data = _data
# > 10364 shifted = data.shift(periods=periods, freq=freq, axis=axis, **kwargs)
#   10365 # Unsupported left operand type for / ("NDFrameT")
#   10366 rs = data / shifted - 1  # type: ignore[operator]
#
# TypeError: shift() got an unexpected keyword argument 'period'

# %%
df = df.rename("Today")
df
# Out:
# Date
# 21-Jul-22     $6.41
# 20-Jul-22     $5.88
# 19-Jul-22     $6.08
# 18-Jul-22     $5.99
# 17-Jul-22     $4.97
#               ...
# 21-Mar-22    $10.50
# 20-Mar-22     $9.60
# 19-Mar-22    $11.56
# 18-Mar-22    $12.96
# 17-Mar-22     $8.52
# Name: Today, Length: 127, dtype: object

# %%
df = df.reset_index()
df
# Out:
#           Date    Today
# 0    21-Jul-22   $6.41
# 1    20-Jul-22   $5.88
# 2    19-Jul-22   $6.08
# 3    18-Jul-22   $5.99
# 4    17-Jul-22   $4.97
# ..         ...      ...
# 122  21-Mar-22  $10.50
# 123  20-Mar-22   $9.60
# 124  19-Mar-22  $11.56
# 125  18-Mar-22  $12.96
# 126  17-Mar-22   $8.52
#
# [127 rows x 2 columns]
